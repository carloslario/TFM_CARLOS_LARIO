# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import itertools
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import time

# %%
te = TransactionEncoder()
dt = pd.read_csv('databasev2.csv', header=None, dtype=str)
dataset = dt.values.tolist()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
frequent_itemsets = apriori(df, min_support=0.005, use_colnames=True)
rules = association_rules(frequent_itemsets, metric ="lift", min_threshold = 0.05) 
rules = rules.sort_values(['lift'], ascending =[False])

# %%
dt.head(5)
# Out:
#           0          1                               2                3  \
# 0  Estacion   Tipo dia        Descripcio_causa_mediata  Descripcio_torn
# 1     Otono  Laborable         No respectar distancies            Tarda
# 2  Invierno  Laborable         No respectar distancies            Tarda
# 3  Invierno  Laborable     Adelantamiento improcedente             Mati
# 4    Verano  Laborable  Manca d'atencio a la conduccio             Mati
#
#                            4              5       6        7
# 0  Descripcio_tipus_accident  Tipo_vehiculo  Genero     Edad
# 1                      Abast    Motocicleta    Home  [18;33]
# 2                      Abast    Motocicleta    Home  [34;50]
# 3           Colision lateral    Motocicleta    Home  [34;50]
# 4              Atropellament    Motocicleta    Dona  [18;33]

# %%
rules.head(15)
# Out:
#                                          antecedents  \
# 19588                        (Tarda, Abast multiple)
# 19593             (No respectar distancies, Turisme)
# 19595                               (Abast multiple)
# 19586      (Tarda, No respectar distancies, Turisme)
# 19413                               (Abast multiple)
# 19404       (Home, No respectar distancies, Turisme)
# 2096              (No respectar distancies, Turisme)
# 2097                                (Abast multiple)
# 19524                               (Abast multiple)
# 19517  (Laborable, No respectar distancies, Turisme)
# 19518                    (Abast multiple, Laborable)
# 19523             (No respectar distancies, Turisme)
# 19411             (No respectar distancies, Turisme)
# 19406                         (Home, Abast multiple)
# 11763                   (Xoc contra element estatic)
#
#                                          consequents  antecedent support  \
# 19588             (No respectar distancies, Turisme)            0.018738
# 19593                        (Tarda, Abast multiple)            0.028600
# 19595      (Tarda, No respectar distancies, Turisme)            0.033379
# 19586                               (Abast multiple)            0.016158
# 19413       (Home, No respectar distancies, Turisme)            0.033379
# 19404                               (Abast multiple)            0.016234
# 2096                                (Abast multiple)            0.028600
# 2097              (No respectar distancies, Turisme)            0.033379
# 19524  (Laborable, No respectar distancies, Turisme)            0.033379
# 19517                               (Abast multiple)            0.022151
# 19518             (No respectar distancies, Turisme)            0.025944
# 19523                    (Abast multiple, Laborable)            0.028600
# 19411                         (Home, Abast multiple)            0.028600
# 19406             (No respectar distancies, Turisme)            0.021545
# 11763          (Nit, Manca d'atencio a la conduccio)            0.028751
#
#        consequent support   support  confidence       lift  leverage  \
# 19588            0.028600  0.005614    0.299595  10.475499  0.005078
# 19593            0.018738  0.005614    0.196286  10.475499  0.005078
# 19595            0.016158  0.005614    0.168182  10.408323  0.005074
# 19586            0.033379  0.005614    0.347418  10.408323  0.005074
# 19413            0.016234  0.005310    0.159091   9.799703  0.004768
# 19404            0.033379  0.005310    0.327103   9.799703  0.004768
# 2096             0.033379  0.009179    0.320955   9.615517  0.008225
# 2097             0.028600  0.009179    0.275000   9.615517  0.008225
# 19524            0.022151  0.007055    0.211364   9.541765  0.006316
# 19517            0.033379  0.007055    0.318493   9.541765  0.006316
# 19518            0.028600  0.007055    0.271930   9.508167  0.006313
# 19523            0.025944  0.007055    0.246684   9.508167  0.006313
# 19411            0.021545  0.005310    0.185676   8.618261  0.004694
# 19406            0.028600  0.005310    0.246479   8.618261  0.004694
# 11763            0.029738  0.006221    0.216359   7.275618  0.005366
#
#        conviction  zhangs_metric
# 19588    1.386913       0.921812
# 19593    1.220911       0.931170
# 19595    1.182760       0.935137
# 19586    1.481225       0.918769
# 19413    1.169884       0.928964
# 19404    1.436506       0.912774
# 2096     1.423501       0.922381
# 2097     1.339863       0.926942
# 19524    1.239923       0.926110
# 19517    1.418359       0.915477
# 19518    1.334213       0.918661
# 19523    1.293024       0.921172
# 19411    1.201556       0.909993
# 19406    1.289148       0.903431
# 11763    1.238146       0.888088

# %%
antecedent_categories = ['Dona','Motocicleta','[34;50]']

consequent_categories = [
    'Colision lateral', 
    'Abast', 'Colision fronto-lateral', 'Caiguda (dues rodes)'
]


# Filtrando las reglas donde los antecedentes y consecuentes contienen cualquier combinación de los ítems de las categorías especificadas
demographic_rules = rules[
    rules['antecedents'].apply(lambda x: len(x) == 3 and all(item in antecedent_categories for item in x)) &
    rules['consequents'].apply(lambda x: len(x) == 1 and all(item in consequent_categories for item in x))
]
demographic_rules.sort_values(['confidence'], ascending=False).head(25)
# Out:
#                         antecedents                consequents  \
# 36902  (Dona, [34;50], Motocicleta)         (Colision lateral)
# 14082  (Dona, [34;50], Motocicleta)                    (Abast)
# 32240  (Dona, [34;50], Motocicleta)  (Colision fronto-lateral)
# 25478  (Dona, [34;50], Motocicleta)     (Caiguda (dues rodes))
#
#        antecedent support  consequent support   support  confidence      lift  \
# 36902            0.070627            0.284782  0.025413    0.359828  1.263520
# 14082            0.070627            0.242831  0.020482    0.290011  1.194290
# 32240            0.070627            0.225080  0.009634    0.136412  0.606063
# 25478            0.070627            0.101578  0.008117    0.114930  1.131449
#
#        leverage  conviction  zhangs_metric
# 36902  0.005300    1.117228       0.224410
# 14082  0.003332    1.066451       0.175045
# 32240 -0.006262    0.897327      -0.411553
# 25478  0.000943    1.015086       0.125006

# %%
antecedent_categories = ['Dona','Furgoneta','[18;33]']

consequent_categories = [
    'Manca d\'atencio a la conduccio', 'No respectar distancies', 'Gir indegut o sense precaucio',
    'Desobeir samoforo', 'Canvi de carril sense precaucio'
]


# Filtrando las reglas donde los antecedentes y consecuentes contienen cualquier combinación de los ítems de las categorías especificadas
demographic_rules = rules[
    rules['antecedents'].apply(lambda x: len(x) == 2 and all(item in antecedent_categories for item in x)) &
    rules['consequents'].apply(lambda x: len(x) == 1 and all(item in consequent_categories for item in x))
]
demographic_rules.sort_values(['confidence'], ascending=False).head(25)
# Out:
#           antecedents                        consequents  antecedent support  \
# 8599  (Dona, [18;33])   (Manca d'atencio a la conduccio)            0.141936
# 8929  (Dona, [18;33])          (No respectar distancies)            0.141936
# 8347  (Dona, [18;33])    (Gir indegut o sense precaucio)            0.141936
# 7813  (Dona, [18;33])                (Desobeir samoforo)            0.141936
# 4825  (Dona, [18;33])  (Canvi de carril sense precaucio)            0.141936
#
#       consequent support   support  confidence      lift  leverage  \
# 8599            0.204445  0.027234    0.191876  0.938519 -0.001784
# 8929            0.143832  0.023365    0.164618  1.144511  0.002950
# 8347            0.124412  0.020179    0.142170  1.142734  0.002520
# 7813            0.095357  0.013200    0.092998  0.975262 -0.000335
# 4825            0.085723  0.010014    0.070551  0.823006 -0.002154
#
#       conviction  zhangs_metric
# 8599    0.984446      -0.070929
# 8929    1.024881       0.147150
# 8347    1.020701       0.145567
# 7813    0.997399      -0.028712
# 4825    0.983676      -0.200404

# %%
antecedent_categories = ['Dona','Motocicleta']

consequent_categories = [
    'Manca d\'atencio a la conduccio', 'No respectar distancies', 'Gir indegut o sense precaucio',
    'Desobeir samoforo', 'Canvi de carril sense precaucio'
]


# Filtrando las reglas donde los antecedentes y consecuentes contienen cualquier combinación de los ítems de las categorías especificadas
demographic_rules = rules[
    rules['antecedents'].apply(lambda x: len(x) == 2 and all(item in antecedent_categories for item in x)) &
    rules['consequents'].apply(lambda x: len(x) == 1 and all(item in consequent_categories for item in x))
]
demographic_rules.sort_values(['confidence'], ascending=False).head(6)
# Out:
#               antecedents                        consequents  \
# 8545  (Motocicleta, Dona)   (Manca d'atencio a la conduccio)
# 8719  (Motocicleta, Dona)          (No respectar distancies)
# 8305  (Motocicleta, Dona)    (Gir indegut o sense precaucio)
# 4802  (Motocicleta, Dona)  (Canvi de carril sense precaucio)
# 7771  (Motocicleta, Dona)                (Desobeir samoforo)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 8545            0.186466            0.204445  0.034972    0.187551  0.917364
# 8719            0.186466            0.143832  0.033075    0.177380  1.233240
# 8305            0.186466            0.124412  0.023972    0.128560  1.033339
# 4802            0.186466            0.085723  0.020938    0.112286  1.309876
# 7771            0.186466            0.095357  0.011227    0.060212  0.631431
#
#       leverage  conviction  zhangs_metric
# 8545 -0.003150    0.979205      -0.099689
# 8719  0.006255    1.040781       0.232477
# 8305  0.000773    1.004760       0.039658
# 4802  0.004953    1.029923       0.290792
# 7771 -0.006554    0.962602      -0.417756

# %%
antecedent_categories = ['[18;33]','[34;50]','[51;70]','Home','Dona','Furgoneta']

consequent_categories = [
    'Manca d\'atencio a la conduccio', 'No respectar distancies', 'Gir indegut o sense precaucio',
    'Desobeir samoforo', 'Canvi de carril sense precaucio'
]


# Filtrando las reglas donde los antecedentes y consecuentes contienen cualquier combinación de los ítems de las categorías especificadas
demographic_rules = rules[
    rules['antecedents'].apply(lambda x: len(x) == 3 and all(item in antecedent_categories for item in x)) &
    rules['consequents'].apply(lambda x: len(x) == 1 and all(item in consequent_categories for item in x))
]
demographic_rules.sort_values(['confidence'], ascending=False).head(25)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %%
antecedent_categories =[
'la Dreta de l\'Eixample','l\'Antiga Esquerra de l\'Eixample','Sant Gervasi - Galvany','la Sagrada Familia','la Nova Esquerra de l\'Eixample'
,'el Fort Pienc','les Corts','Sant Gervasi - la Bonanova','Sant Antoni','la Marina del Prat Vermell','la Maternitat i Sant Ramon','el Poble-sec',
'el Camp de l\'Arpa del Clot','Provensals del Poblenou','el Bon Pastor','Sarria','Pedralbes','el Clot','el Poblenou','Sants','Sant Andreu','Horta',
'el Baix Guinardo','la Barceloneta','la Vila de Gracia','les Tres Torres','la Marina de Port'
]

consequent_categories = [
    'Manca d\'atencio a la conduccio', 'No respectar distancies', 'Gir indegut o sense precaucio',
    'Desobeir samoforo', 'Canvi de carril sense precaucio'
]


# Filtrando las reglas donde los antecedentes y consecuentes contienen cualquier combinación de los ítems de las categorías especificadas
filtered_rules = rules[
      rules['antecedents'].apply(lambda x: all(item in antecedent_categories for item in x)) &
    rules['consequents'].apply(lambda x: all(item in consequent_categories for item in x))
]
filtered_rules.sort_values(['lift'], ascending=False).head(25)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %%
antecedent_categories =[
'la Dreta de l\'Eixample','l\'Antiga Esquerra de l\'Eixample','Sant Gervasi - Galvany','la Sagrada Familia','la Nova Esquerra de l\'Eixample'
,'el Fort Pienc','les Corts','Sant Gervasi - la Bonanova','Sant Antoni','la Marina del Prat Vermell','la Maternitat i Sant Ramon','el Poble-sec',
'el Camp de l\'Arpa del Clot','Provensals del Poblenou','el Bon Pastor','Sarria','Pedralbes','el Clot','el Poblenou','Sants','Sant Andreu','Horta',
'el Baix Guinardo','la Barceloneta','la Vila de Gracia','les Tres Torres','la Marina de Port'
]

consequent_categories = [
    'Colision lateral', 
    'Abast', 'Colision fronto-lateral', 'Caiguda (dues rodes)','Abast multiple'
]


# Filtrando las reglas donde los antecedentes y consecuentes contienen cualquier combinación de los ítems de las categorías especificadas
filtered_rules = rules[
      rules['antecedents'].apply(lambda x: all(item in antecedent_categories for item in x)) &
    rules['consequents'].apply(lambda x: all(item in consequent_categories for item in x))
]
filtered_rules.sort_values(['lift'], ascending=False).head(25)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %%
antecedent_categories =[
    'Eixample','Sant Marti','Sarria -Sant Gervasi','Sants-Montjuic','Horta-Guinardo','Les Corts'
]

consequent_categories = [
    'Colision lateral', 
    'Abast', 'Colision fronto-lateral', 'Caiguda (dues rodes)','Abast multiple'
]


# Filtrando las reglas donde los antecedentes y consecuentes contienen cualquier combinación de los ítems de las categorías especificadas
filtered_rules = rules[
      rules['antecedents'].apply(lambda x: all(item in antecedent_categories for item in x)) &
    rules['consequents'].apply(lambda x: all(item in consequent_categories for item in x))
]
filtered_rules.sort_values(['lift'], ascending=False).head(25)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %%
antecedent_categories = [
    'Colision lateral', 
    'Abast', 'Colision fronto-lateral', 'Caiguda (dues rodes)','Abast multiple'
]

consequent_categories = [
    'Manca d\'atencio a la conduccio', 'No respectar distancies', 'Gir indegut o sense precaucio',
    'Desobeir samoforo', 'Canvi de carril sense precaucio'
]


# Filtrando las reglas donde los antecedentes y consecuentes contienen cualquier combinación de los ítems de las categorías especificadas
filtered_rules = rules[
      rules['antecedents'].apply(lambda x: all(item in antecedent_categories for item in x)) &
    rules['consequents'].apply(lambda x: all(item in consequent_categories for item in x))
]
filtered_rules.sort_values(['lift'], ascending=False).head(25)
# Out:
#                    antecedents                        consequents  \
# 335  (Colision fronto-lateral)                (Desobeir samoforo)
# 62            (Abast multiple)          (No respectar distancies)
# 28                     (Abast)          (No respectar distancies)
# 269         (Colision lateral)  (Canvi de carril sense precaucio)
# 389         (Colision lateral)    (Gir indegut o sense precaucio)
# 54            (Abast multiple)   (Manca d'atencio a la conduccio)
# 16                     (Abast)   (Manca d'atencio a la conduccio)
# 240     (Caiguda (dues rodes))   (Manca d'atencio a la conduccio)
# 227     (Caiguda (dues rodes))  (Canvi de carril sense precaucio)
# 339  (Colision fronto-lateral)    (Gir indegut o sense precaucio)
# 228     (Caiguda (dues rodes))                (Desobeir samoforo)
# 232     (Caiguda (dues rodes))    (Gir indegut o sense precaucio)
# 397         (Colision lateral)   (Manca d'atencio a la conduccio)
# 5                      (Abast)  (Canvi de carril sense precaucio)
# 347  (Colision fronto-lateral)   (Manca d'atencio a la conduccio)
# 385         (Colision lateral)                (Desobeir samoforo)
# 411         (Colision lateral)          (No respectar distancies)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 335            0.225080            0.095357  0.077985    0.346478  3.633470
# 62             0.033379            0.143832  0.016310    0.488636  3.397260
# 28             0.242831            0.143832  0.112805    0.464542  3.229745
# 269            0.284782            0.085723  0.062282    0.218700  2.551243
# 389            0.284782            0.124412  0.080640    0.283165  2.276022
# 54             0.033379            0.204445  0.014338    0.429545  2.101027
# 16             0.242831            0.204445  0.092323    0.380194  1.859634
# 240            0.101578            0.204445  0.023213    0.228529  1.117798
# 227            0.101578            0.085723  0.009255    0.091113  1.062875
# 339            0.225080            0.124412  0.028903    0.128413  1.032155
# 228            0.101578            0.095357  0.005462    0.053771  0.563895
# 232            0.101578            0.124412  0.005993    0.058999  0.474224
# 397            0.284782            0.204445  0.021924    0.076985  0.376553
# 5              0.242831            0.085723  0.007434    0.030615  0.357144
# 347            0.225080            0.204445  0.016310    0.072464  0.354441
# 385            0.284782            0.095357  0.005159    0.018114  0.189959
# 411            0.284782            0.143832  0.007662    0.026905  0.187055
#
#      leverage  conviction  zhangs_metric
# 335  0.056522    1.384257       0.935297
# 62   0.011509    1.674283       0.730012
# 28   0.077878    1.598945       0.911789
# 269  0.037870    1.170200       0.850139
# 389  0.045210    1.221463       0.783869
# 54   0.007514    1.394598       0.542138
# 16   0.042677    1.283553       0.610511
# 240  0.002446    1.031217       0.117299
# 227  0.000547    1.005930       0.065844
# 339  0.000900    1.004590       0.040202
# 228 -0.004224    0.956051      -0.462603
# 232 -0.006644    0.930486      -0.552384
# 397 -0.036299    0.861908      -0.698333
# 5   -0.013382    0.943152      -0.703902
# 347 -0.029706    0.857707      -0.701525
# 385 -0.021998    0.921332      -0.856368
# 411 -0.033299    0.879839      -0.858687

# %%
antecedent_categories =[
    'Eixample','Sant Marti','Sarria -Sant Gervasi','Sants-Montjuic','Horta-Guinardo','Les Corts'
]

consequent_categories = [
    'Manca d\'atencio a la conduccio', 'No respectar distancies', 'Gir indegut o sense precaucio',
    'Desobeir samoforo', 'Canvi de carril sense precaucio'
]


# Filtrando las reglas donde los antecedentes y consecuentes contienen cualquier combinación de los ítems de las categorías especificadas
filtered_rules = rules[
      rules['antecedents'].apply(lambda x: all(item in antecedent_categories for item in x)) &
    rules['consequents'].apply(lambda x: all(item in consequent_categories for item in x))
]
filtered_rules.sort_values(['lift'], ascending=False).head(25)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []
